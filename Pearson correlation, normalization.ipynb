# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # Importing data

# %%
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

# %%
path_x = r'C:\Users\Adamin\Documents\Alpha'
path = r'/vol/sci/astro/bigdata/tussbaum/halofinder/catalog/'
path_1 = r'/vol/sci/astro/home/adambeilialpha/'

# %%
sgal_qlabel_0 = pd.read_pickle(path_1 + r'/sgal_qlabel_0.pkl')
sgal_qlabel_1 = pd.read_pickle(path_1 + r'/sgal_qlabel_1.pkl')
sgal_features = pd.concat([sgal_qlabel_0, sgal_qlabel_1], axis=1)

# %%
print '# Rows: ', len(sgal_features), '# Columns: ', len(sgal_features.keys().values), '\n', sgal_features.keys().values
# Out:
# # Rows:  118 # Columns:  54
# [u'CGH_gas_density(Rorbit+-Rsat)[Msun/kpc^3]' u'Mcg(Rcoldgass_0.9)[Msun]'
#  u'Mcg(Rsat)[Msun]' u'Mdm(R0.5kpc)[Msun]' u'Mdm(Rsat)[Msun]'
#  u'Mgas(R0.5kpc)[Msun]' u'Mgas(Rsat)[Msun]' u'Mstar(R0.5kpc)[Msun]'
#  u'Mstar(Rsat)[Msun]' u'Mstar_young(R0.5kpc)[Msun]'
#  u'Mstar_young(Rsat)[Msun]' u'Mtot(R0.5kpc)[Msun]' u'Mtot(Rsat)[Msun]'
#  u'Rorbit-Rvir[kpc]' u'Rorbit[kpc]' u'Rsat[kpc]' u'Vorbit[km/s]'
#  u'c(Rsat/Reff)' u'Rsat/Rvir[kpc]' u'center_Mstar(0.1rvir)[Msun]'
#  u'center_Rvir[kpc]' u'theta(Vorbit*Rorbit)' 'qlabel(1|4)'
#  'Rorbit(peri_1)/R_vir(kpc)' 'Mcg(R0.5kpc)[Msun]' 'Msat/Mrvir'
#  'gas_c_vec*Vorbit(0.9coldgas)' 'gas_c_vec*gas_AM(0.9coldgas)'
#  'stars_AM*Vorbit(0.9coldgas)' 'gas_c_vec*stars_AM(0.9coldgas)'
#  'stars_AM*Vorbit(0.5kpc)' 'stars_AM*Vorbit(Rsat)' 'stars_AM*dm_AM(Rsat)'
#  u'density(R0.5kpc)[Msun/kpc^3]' u'density(R1kpc)[Msun/kpc^3]'
#  u'density(Rsat)[Msun/kpc^3]' u'sigma(R0.5kpc)[Msun/kpc^2]'
# ...

# %% [markdown]
# ## Normalizing Data

# %%
 = sgal_features[['CGH_gas_density(Rorbit+-Rsat)[Msun/kpc^3]','Rorbit-Rvir[kpc]','Vorbit[km/s]','c(Rsat/Reff)','Rsat/Rvir[kpc]',
                                          'theta(Vorbit*Rorbit)','gas_c_vec*Vorbit(0.9coldgas)','gas_c_vec*gas_AM(0.9coldgas)','stars_AM*Vorbit(0.9coldgas)',
                                          'gas_c_vec*stars_AM(0.9coldgas)','stars_AM*Vorbit(0.5kpc)','stars_AM*Vorbit(Rsat)','stars_AM*dm_AM(Rsat)',
                                          'stars_p(0.5kpc)','stars_q(0.5kpc)','dm_p(0.5kpc)','dm_q(0.5kpc)','gas_p(0.5kpc)','gas_q(0.5kpc)',
                                          'stars_p(Rsat)','stars_q(Rsat)','dm_p(Rsat)','dm_q(Rsat)','gas_p(0.9coldgas)','gas_q(0.9coldgas)','qlabel(1|4)']]

# %%
sgal_features['Mcg(Rcoldgass_0.9)[Msun]'].dropna()
a=np.log(sgal_features['Mcg(Rcoldgass_0.9)[Msun]'].fillna(1.0).astype(float))

# %%
sgal_features_normalized['Mcg(Rcoldgass_0.9)[Msun]'] = np.log(sgal_features['Mcg(Rcoldgass_0.9)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mcg(Rsat)[Msun]'] = np.log(sgal_features['Mcg(Rsat)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mdm(R0.5kpc)[Msun]'] = np.log(sgal_features['Mdm(R0.5kpc)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mdm(Rsat)[Msun]'] = np.log(sgal_features['Mdm(Rsat)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mgas(R0.5kpc)[Msun]'] = np.log(sgal_features['Mgas(R0.5kpc)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mgas(Rsat)[Msun]'] = np.log(sgal_features['Mgas(Rsat)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mstar(R0.5kpc)[Msun]'] = np.log(sgal_features['Mstar(R0.5kpc)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mstar(Rsat)[Msun]'] = np.log(sgal_features['Mstar(Rsat)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mstar_young(R0.5kpc)[Msun]'] = np.log(sgal_features['Mstar_young(R0.5kpc)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mstar_young(Rsat)[Msun]'] = np.log(sgal_features['Mstar_young(Rsat)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mtot(R0.5kpc)[Msun]'] = np.log(sgal_features['Mtot(R0.5kpc)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Mtot(Rsat)[Msun]'] = np.log(sgal_features['Mtot(Rsat)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Rorbit[kpc]'] = np.log(sgal_features['Rorbit[kpc]'].fillna(1.0).astype(float))
sgal_features_normalized['Rsat[kpc]'] = np.log(sgal_features['Rsat[kpc]'].fillna(1.0).astype(float))
sgal_features_normalized['center_Mstar(0.1rvir)[Msun]'] = np.log(sgal_features['center_Mstar(0.1rvir)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['center_Rvir[kpc]'] = np.log(sgal_features['center_Rvir[kpc]'].fillna(1.0).astype(float))
sgal_features_normalized['Rorbit(peri_1)/R_vir(kpc)'] = np.log(sgal_features['Rorbit(peri_1)/R_vir(kpc)'].fillna(1.0).astype(float))
sgal_features_normalized['Mcg(R0.5kpc)[Msun]'] = np.log(sgal_features['Mcg(R0.5kpc)[Msun]'].fillna(1.0).astype(float))
sgal_features_normalized['Msat/Mrvir'] = np.log(sgal_features['Msat/Mrvir'].fillna(1.0).astype(float))
sgal_features_normalized['density(R0.5kpc)[Msun/kpc^3]'] = np.log(sgal_features['density(R0.5kpc)[Msun/kpc^3]'].fillna(1.0).astype(float))
sgal_features_normalized['density(R1kpc)[Msun/kpc^3]'] = np.log(sgal_features['density(R1kpc)[Msun/kpc^3]'].fillna(1.0).astype(float))
sgal_features_normalized['density(Rsat)[Msun/kpc^3]'] = np.log(sgal_features['density(Rsat)[Msun/kpc^3]'].fillna(1.0).astype(float))
sgal_features_normalized['sigma(R0.5kpc)[Msun/kpc^2]'] = np.log(sgal_features['sigma(R0.5kpc)[Msun/kpc^2]'].fillna(1.0).astype(float))
sgal_features_normalized['sigma(Rsat)[Msun/kpc^2]'] = np.log(sgal_features['sigma(Rsat)[Msun/kpc^2]'].fillna(1.0).astype(float))
sgal_features_normalized['ssfr(R0.5kpc)[1/yr]'] = np.log(sgal_features['ssfr(R0.5kpc)[1/yr]'].fillna(1.0).astype(float))
sgal_features_normalized['ssfr(Rsat)[1/yr]'] = np.log(sgal_features['ssfr(Rsat)[1/yr]'].fillna(1.0).astype(float))
# Out:
# /vol/sci/astro/home/adambeilialpha/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /vol/sci/astro/home/adambeilialpha/.local/lib/python2.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# /vol/sci/astro/home/adambeilialpha/.local/lib/python2.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.
# /vol/sci/astro/home/adambeilialpha/.local/lib/python2.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log
# /vol/sci/astro/home/adambeilialpha/.local/lib/python2.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in log
# /vol/sci/astro/home/adambeilialpha/.local/lib/python2.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: divide by zero encountered in log

# %%
print '# Rows: ', len(sgal_features_normalized), '# Columns: ', len(sgal_features_normalized.keys().values), '\n', sgal_features_normalized.keys().values
# Out:
# # Rows:  118 # Columns:  52
# [u'CGH_gas_density(Rorbit+-Rsat)[Msun/kpc^3]' u'Rorbit-Rvir[kpc]'
#  u'Vorbit[km/s]' u'c(Rsat/Reff)' u'Rsat/Rvir[kpc]' u'theta(Vorbit*Rorbit)'
#  'gas_c_vec*Vorbit(0.9coldgas)' 'gas_c_vec*gas_AM(0.9coldgas)'
#  'stars_AM*Vorbit(0.9coldgas)' 'gas_c_vec*stars_AM(0.9coldgas)'
#  'stars_AM*Vorbit(0.5kpc)' 'stars_AM*Vorbit(Rsat)' 'stars_AM*dm_AM(Rsat)'
#  u'stars_p(0.5kpc)' u'stars_q(0.5kpc)' u'dm_p(0.5kpc)' u'dm_q(0.5kpc)'
#  u'gas_p(0.5kpc)' u'gas_q(0.5kpc)' u'stars_p(Rsat)' u'stars_q(Rsat)'
#  u'dm_p(Rsat)' u'dm_q(Rsat)' u'gas_p(0.9coldgas)' u'gas_q(0.9coldgas)'
#  'qlabel(1|4)' 'Mcg(Rcoldgass_0.9)[Msun]' 'Mcg(Rsat)[Msun]'
#  'Mdm(R0.5kpc)[Msun]' 'Mdm(Rsat)[Msun]' 'Mgas(R0.5kpc)[Msun]'
#  'Mgas(Rsat)[Msun]' 'Mstar(R0.5kpc)[Msun]' 'Mstar(Rsat)[Msun]'
#  'Mstar_young(R0.5kpc)[Msun]' 'Mstar_young(Rsat)[Msun]'
#  'Mtot(R0.5kpc)[Msun]' 'Mtot(Rsat)[Msun]' 'Rorbit[kpc]' 'Rsat[kpc]'
#  'center_Mstar(0.1rvir)[Msun]' 'center_Rvir[kpc]'
# ...

# %% [markdown]
# ### Histograms: OG vs Normalized

# %%
print sns.distplot(a)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print sns.distplot(sgal_features['Mcg(Rcoldgass_0.9)[Msun]'].dropna())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
b=np.log(sgal_features['theta(Vorbit*Rorbit)'].dropna().astype(float))
#b=sgal_features['theta(Vorbit*Rorbit)']
print sns.distplot(b.replace([np.inf, -np.inf], np.nan).dropna())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sgal_features.drop

# %% [markdown]
# # Pearson Correlation Graph

# %%
sns.set(style="white")

sgal_qlabel_surv = sgal_features.loc[sgal_features['qlabel(1|4)']!=0]
sgal_qlabel_surv = sgal_qlabel_surv.replace([np.inf, -np.inf], np.nan).dropna()
sgal_qlabel_surv = sgal_qlabel_surv.reset_index().drop(['tgid'],axis=1)

# Compute the correlation matrix
corr = sgal_qlabel_surv.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(70, 60))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Before Normalization

# %%
mask=(corr['qlabel(1|4)']**2)>=0.1
important_features = corr['qlabel(1|4)'][mask]

# %%
important_features

# %%
sgal_qlabel_surv = sgal_features_normalized.loc[sgal_features_normalized['qlabel(1|4)']!=0]
sgal_qlabel_surv = sgal_qlabel_surv.replace([np.inf, -np.inf,0], np.nan).dropna()
print '# Rows: ', len(sgal_qlabel_surv), '# Columns: ', len(sgal_qlabel_surv.keys().values), '\n',# sgal_qlabel_surv.keys().values
# Out:
# # Rows:  80 # Columns:  52

# %% [markdown]
# ## After Normalization

# %%
sns.set(style="white")

sgal_qlabel_surv = sgal_features_normalized.loc[sgal_features_normalized['qlabel(1|4)']!=0]
sgal_qlabel_surv = sgal_qlabel_surv.replace([np.inf, -np.inf,0], np.nan).dropna()
sgal_qlabel_surv = sgal_qlabel_surv.reset_index().drop(['tgid'],axis=1)

# Compute the correlation matrix
corr = sgal_qlabel_surv.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(70, 60))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
mask=(corr['qlabel(1|4)']**2)>=0.1
important_features_normalized = corr['qlabel(1|4)'][mask]

# %%
important_features_normalized
# Out:
# qlabel(1|4)                     1.000000
# Mcg(Rcoldgass_0.9)[Msun]        0.457564
# Mcg(Rsat)[Msun]                 0.516973
# Mdm(R0.5kpc)[Msun]              0.357762
# Mdm(Rsat)[Msun]                 0.481405
# Mgas(R0.5kpc)[Msun]             0.360414
# Mgas(Rsat)[Msun]                0.519434
# Mstar(R0.5kpc)[Msun]            0.520115
# Mstar(Rsat)[Msun]               0.554430
# Mstar_young(R0.5kpc)[Msun]      0.387190
# Mstar_young(Rsat)[Msun]         0.434383
# Mtot(R0.5kpc)[Msun]             0.519654
# Mtot(Rsat)[Msun]                0.537578
# Rsat[kpc]                       0.409052
# Mcg(R0.5kpc)[Msun]              0.352462
# Msat/Mrvir                      0.484960
# density(R0.5kpc)[Msun/kpc^3]    0.520115
# density(R1kpc)[Msun/kpc^3]      0.534665
# density(Rsat)[Msun/kpc^3]       0.348769
# sigma(R0.5kpc)[Msun/kpc^2]      0.520115
# sigma(Rsat)[Msun/kpc^2]         0.499023
# Name: qlabel(1|4), dtype: float64

# %%
print important_features,'\n','\n',important_features_normalized
# Out:
# Mcg(Rcoldgass_0.9)[Msun]        0.396314
# Mcg(Rsat)[Msun]                 0.500710
# Mdm(R0.5kpc)[Msun]              0.469421
# Mdm(Rsat)[Msun]                 0.521141
# Mgas(R0.5kpc)[Msun]             0.388407
# Mgas(Rsat)[Msun]                0.498700
# Mstar(R0.5kpc)[Msun]            0.458007
# Mstar(Rsat)[Msun]               0.542477
# Mstar_young(Rsat)[Msun]         0.391147
# Mtot(R0.5kpc)[Msun]             0.488779
# Mtot(Rsat)[Msun]                0.546137
# Rsat[kpc]                       0.411941
# qlabel(1|4)                     1.000000
# Mcg(R0.5kpc)[Msun]              0.387350
# Msat/Mrvir                      0.453209
# density(R0.5kpc)[Msun/kpc^3]    0.458007
# density(R1kpc)[Msun/kpc^3]      0.484345
# density(Rsat)[Msun/kpc^3]       0.360060
# sigma(R0.5kpc)[Msun/kpc^2]      0.458007
# sigma(Rsat)[Msun/kpc^2]         0.439603
# zana_mass                       0.522047
# zana_r                          0.564691
# Name: qlabel(1|4), dtype: float64
#
# ...
